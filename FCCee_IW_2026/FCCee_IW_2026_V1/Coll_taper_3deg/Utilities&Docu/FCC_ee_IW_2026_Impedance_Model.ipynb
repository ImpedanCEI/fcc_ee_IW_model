# %% [markdown]
# # FCC-ee Impedance/Wake Model

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path
import matplotlib as mpl
import matplotlib.patches as mpatches
from matplotlib.ticker import LogLocator

# %% [markdown]
# ## Impedance/Wake (I/W) Model plotting : more info in readme

# %% [markdown]
# ### Reading of device impedance from Impedance folder

# %%
from pathlib import Path
import numpy as np

def read_impedance_devices(folder, plane):
    """
    Read impedance files from Devices folder.
    """

    folder = Path(folder)
    devices = {}

    pattern = f"Z_{plane}_*.txt"
    files = sorted(folder.glob(pattern))

    print("Looking in:", folder.resolve())
    print("Pattern:", pattern)
    print("Files found:")
    for f in files:
        print("  ", f.name)

    if len(files) == 0:
        raise FileNotFoundError(
            f"No files found with pattern '{pattern}' in:\n{folder.resolve()}"
        )

    freq_ref = None

    for f in files:

        data = np.loadtxt(f, comments="#")

        freq = data[:, 0]
        Z = data[:, 1] + 1j * data[:, 2]

        # Example:
        # Z_dipx_bpm.txt -> bpm
        # Z_dipx_coll3cm.txt -> coll3cm
        name = f.stem.replace(f"Z_{plane}_", "")

        devices[name] = Z

        if freq_ref is None:
            freq_ref = freq
        else:
            if len(freq) != len(freq_ref) or not np.allclose(freq, freq_ref):
                raise ValueError(
                    f"Frequency grid mismatch in file '{f.name}'.\n"
                    "All files should have the same frequency grid after interpolation."
                )

    return freq_ref, devices


def read_total_impedance(folder, plane):
    """
    Read total impedance file.

    Expected filename:
        Z_tot_dipx.txt
        Z_tot_dipy.txt
        Z_tot_long.txt

    """

    folder = Path(folder)

    possible_files = [
        folder / f"Z_tot_{plane}.txt",
        folder / f"Z_{plane}.txt",
    ]

    file = None

    for candidate in possible_files:
        if candidate.exists():
            file = candidate
            break

    if file is None:
        raise FileNotFoundError(
            f"No total impedance file found for plane '{plane}' in:\n"
            f"{folder.resolve()}\n\n"
            f"I searched for:\n"
            f"  Z_tot_{plane}.txt\n"
            f"  Z_{plane}.txt"
        )

    data = np.loadtxt(file, comments="#")

    freq = data[:, 0]
    Z = data[:, 1] + 1j * data[:, 2]

    return freq, Z

# %% [markdown]
# ### Colour Plot of impedance device contribution

# %%
def plot_stacked_impedance(frequency, Z_contributions, labels, colors,
                          plane="dipy", part="imag"):

    plane_label_map = {
        "dipx": r"$Z_{x}$",
        "dipy": r"$Z_{y}$",
        "long": r"$Z_{long}$"
    }

    unit_map = {
        "dipx": r"($\Omega$/m)",
        "dipy": r"($\Omega$/m)",
        "long": r"($\Omega$)"
    }

    part_label_map = {
        "real": "Re",
        "imag": "Im"
    }

    part_name_map = {
        "real": "Re",
        "imag": "Im"
    }

    y_label = f"{part_label_map[part]}[{plane_label_map[plane]}] {unit_map[plane]}"
    filename = f"Z_{plane}_{part_name_map[part]}_log_area.jpg"

    # ---------------- Plot ----------------
    fntsz = 18
    mpl.rcParams.update({
        'font.size': fntsz,
        'axes.titlesize': fntsz,
        'axes.labelsize': fntsz,
        'xtick.labelsize': fntsz,
        'ytick.labelsize': fntsz,
        'legend.fontsize': fntsz-2
    })

    image_folder = Path.cwd().parent / "Plots"
    image_folder.mkdir(exist_ok=True)

    plt.close('all')
    fig, ax = plt.subplots(figsize=(10,7.5))

    ax.set_xlabel('f (GHz)')
    ax.set_ylabel(y_label)

    values = [Z.real if part=="real" else Z.imag for Z in Z_contributions]

    for Z, c in zip(values, colors):
        ax.fill_between(frequency, Z, color=c, alpha=1)

    legend_patches = [mpatches.Patch(color=c, label=l) for c,l in zip(colors,labels)]
    ax.legend(handles=legend_patches, loc='upper right', bbox_to_anchor=(1.015,1.02))

    ax.set_xlim(1e-3,10)
    ax.set_ylim(1e-0, 1e10)

    ax.set_yscale('log')
    ax.set_xscale('linear')

    ax.yaxis.set_major_locator(LogLocator(base=10.0, subs=(1.0,), numticks=8))
    ax.yaxis.set_minor_locator(LogLocator(base=10.0, subs=np.arange(2,10)*0.1, numticks=40))
    ax.tick_params(axis='y', which='minor', length=1.5, width=0.3)

    fig.subplots_adjust(left=0.12,right=0.93,bottom=0.15,top=0.92)

    plt.savefig(image_folder / filename, dpi=300, bbox_inches='tight')
    plt.show()

    #print(f"Saved: {filename}")

# %%
devices_folder = Path.cwd().parent / "Impedances" /"Devices"

frequency, devices = read_impedance_devices(devices_folder, "dipy")


Z_contributions_dipy = [
    devices["kickers"],
    devices["coll3cm"],
    devices["pipe_rw"],
    devices["SRabs"],
    devices["ems"],
    devices["stripkickers26"],
    devices["IR"],
    devices["flanges"],
    devices["int_mod"],
    devices["bpm"],
    devices["RF"]
]

colors = ['purple',
    'orange', 'blue', 'limegreen', 'steelblue', 'salmon',
    'cyan', 'magenta', 'yellow', 'brown', 'gray'
]

labels = ['kickers',
    'collimators', 'beam pipe RW', 'SR abs.', 'ems',
    'strip. kickers', 'IR', 'flanges', 'int. mod',
    'bpm', 'RF'
]

plot_stacked_impedance(
    frequency, Z_contributions_dipy, labels, colors,
    plane="dipy", part="imag"
)

plot_stacked_impedance(
    frequency, Z_contributions_dipy, labels, colors,
    plane="dipy", part="real"
)
# Out:
# Looking in: /home/cantuono/fcc_ee_IW_model/FCCee_IW_2026/FCCee_IW_2026_V1/Coll_taper_3deg/Impedances/Devices
# Pattern: Z_dipy_*.txt
# Files found:
#    Z_dipy_IR.txt
#    Z_dipy_RF.txt
#    Z_dipy_SRabs.txt
#    Z_dipy_bpm.txt
#    Z_dipy_coll3cm.txt
#    Z_dipy_ems.txt
#    Z_dipy_flanges.txt
#    Z_dipy_int_mod.txt
#    Z_dipy_kickers.txt
#    Z_dipy_pipe_rw.txt
#    Z_dipy_stripkickers18mm.txt
#    Z_dipy_stripkickers26.txt

# %%
devices_folder = Path.cwd().parent / "Impedances" /"Devices"

frequency, devices = read_impedance_devices(devices_folder, "dipx")


Z_contributions_dipx = [
    devices["kickers"],
    devices["coll3cm"],
    devices["pipe_rw"],
    devices["SRabs"],
    devices["ems"],
    devices["stripkickers26"],
    devices["IR"],
    devices["flanges"],
    devices["int_mod"],
    devices["bpm"],
    devices["RF"]
]

colors = ['purple',
    'orange', 'blue', 'limegreen', 'steelblue', 'salmon',
    'cyan', 'magenta', 'yellow', 'brown', 'gray'
]

labels = ['kickers',
    'collimators', 'beam pipe RW', 'SR abs.', 'ems',
    'strip. kickers', 'IR', 'flanges', 'int. mod',
    'bpm', 'RF'
]

plot_stacked_impedance(
    frequency, Z_contributions_dipx, labels, colors,
    plane="dipx", part="imag"
)

plot_stacked_impedance(
    frequency, Z_contributions_dipx, labels, colors,
    plane="dipx", part="real"
)
# Out:
# Looking in: /home/cantuono/fcc_ee_IW_model/FCCee_IW_2026/FCCee_IW_2026_V1/Coll_taper_3deg/Impedances/Devices
# Pattern: Z_dipx_*.txt
# Files found:
#    Z_dipx_IR.txt
#    Z_dipx_RF.txt
#    Z_dipx_SRabs.txt
#    Z_dipx_bpm.txt
#    Z_dipx_coll3cm.txt
#    Z_dipx_ems.txt
#    Z_dipx_flanges.txt
#    Z_dipx_int_mod.txt
#    Z_dipx_kickers.txt
#    Z_dipx_pipe_rw.txt
#    Z_dipx_stripkickers18mm.txt
#    Z_dipx_stripkickers26.txt

# %%
devices_folder = Path.cwd().parent / "Impedances" /"Devices"

frequency, devices = read_impedance_devices(devices_folder, "long")

Z_contributions_long = [
    devices["kickers"],
    devices["coll3cm"],
    devices["pipe_rw"],
    devices["SRabs"],
    devices["ems"],
    devices["stripkickers26"],
    devices["IR"],
    devices["flanges"],
    devices["int_mod"],
    devices["bpm"],
    devices["RF"]
]

colors = ['purple',
    'orange', 'blue', 'limegreen', 'steelblue', 'salmon',
    'cyan', 'magenta', 'yellow', 'brown', 'gray'
]

labels = ['kickers',
    'collimators', 'beam pipe RW', 'SR abs.', 'ems',
    'strip. kickers', 'IR', 'flanges', 'int. mod',
    'bpm', 'RF'
]

plot_stacked_impedance(
    frequency, Z_contributions_long, labels, colors,
    plane="long", part="imag"
)

plot_stacked_impedance(
    frequency, Z_contributions_long, labels, colors,
    plane="long", part="real"
)
# Out:
# Looking in: /home/cantuono/fcc_ee_IW_model/FCCee_IW_2026/FCCee_IW_2026_V1/Coll_taper_3deg/Impedances/Devices
# Pattern: Z_long_*.txt
# Files found:
#    Z_long_IR.txt
#    Z_long_RF.txt
#    Z_long_SRabs.txt
#    Z_long_bpm.txt
#    Z_long_coll3cm.txt
#    Z_long_ems.txt
#    Z_long_flanges.txt
#    Z_long_int_mod.txt
#    Z_long_kickers.txt
#    Z_long_pipe_rw.txt
#    Z_long_stripkickers18mm.txt
#    Z_long_stripkickers26.txt

# %% [markdown]
# ### Plot of Total impedance

# %%
def plot_dipoles(freq_x, Zx, freq_y, Zy, part, image_folder, scale="log"):
    """
    part  : 'real' or 'imag'
    scale : 'log' or 'linear'
    """

    plt.close('all')
    fig, ax = plt.subplots(figsize=(7,5))

    ax.set_xlabel('f (GHz)')

    # ---------- Select data ----------
    if part == "real":
        yx = Zx.real
        yy = Zy.real
        ylabel = r'Re[$Z_{dip}$] ($\Omega$/m)'
        name_part = "Re"

    elif part == "imag":
        yx = Zx.imag
        yy = Zy.imag
        ylabel = r'Im[$Z_{dip}$] ($\Omega$/m)'
        name_part = "Im"

    else:
        raise ValueError("part must be 'real' or 'imag'")

    ax.set_ylabel(ylabel)

    # ---------- Plot ----------
    ax.plot(freq_x, yx, lw=2, label=r'$Z_x$ dipole')
    ax.plot(freq_y, yy, lw=2, label=r'$Z_y$ dipole')

    ax.set_xlim(1e-3, 20)

    # ---------- Scale ----------
    if scale == "log":
        ax.set_yscale('log')
        ax.yaxis.set_major_locator(LogLocator(base=10.0))
        ax.yaxis.set_minor_locator(LogLocator(base=10.0, subs=np.arange(2,10)*0.1))

    elif scale == "linear":
        ax.set_yscale('linear')

    else:
        raise ValueError("scale must be 'log' or 'linear'")

    ax.set_xscale('linear')

    ax.legend()
    fig.subplots_adjust(left=0.12,right=0.93,bottom=0.15,top=0.92)

    filename = f"Z_total_dipole_{name_part}_{scale}.jpg"
    plt.savefig(image_folder / filename, dpi=300, bbox_inches='tight')

    plt.show()



def plot_longitudinal(freq, Z, part, image_folder, scale="log"):
    """
    part  : 'real' or 'imag'
    scale : 'log' or 'linear'
    """

    plt.close('all')
    fig, ax = plt.subplots(figsize=(7,5))

    ax.set_xlabel('f (GHz)')

    # ---------- Select data ----------
    if part == "real":
        y = Z.real
        ylabel = r'Re[$Z_{long}$] ($\Omega$)'
        name_part = "Re"

    elif part == "imag":
        y = Z.imag
        ylabel = r'Im[$Z_{long}$] ($\Omega$)'
        name_part = "Im"

    else:
        raise ValueError("part must be 'real' or 'imag'")

    ax.set_ylabel(ylabel)

    # ---------- Plot ----------
    ax.plot(freq, y, lw=2, label=r'$Z_{long}$')

    ax.set_xlim(1e-3, 20)

    # ---------- Scale ----------
    if scale == "log":
        ax.set_yscale('log')
        ax.yaxis.set_major_locator(LogLocator(base=10.0))
        ax.yaxis.set_minor_locator(LogLocator(base=10.0, subs=np.arange(2,10)*0.1))

    elif scale == "linear":
        ax.set_yscale('linear')

    else:
        raise ValueError("scale must be 'log' or 'linear'")

    ax.set_xscale('linear')

    ax.legend()
    fig.subplots_adjust(left=0.12,right=0.93,bottom=0.15,top=0.92)

    filename = f"Z_total_longitudinal_{name_part}_{scale}.jpg"
    plt.savefig(image_folder / filename, dpi=300, bbox_inches='tight')

    plt.show()

# %%
total_folder = Path.cwd().parent / "Impedances" / "Devices"

freq_x, Zx_tot = read_total_impedance(total_folder, "dipx")
freq_y, Zy_tot = read_total_impedance(total_folder, "dipy")
freq_z, Zz_tot = read_total_impedance(total_folder, "long")

# %%
image_folder = Path.cwd().parent / "Plots" 
# REAL part
plot_dipoles(freq_x, Zx_tot, freq_y, Zy_tot,part="real", image_folder=image_folder, scale="linear")

# IMAG part
plot_dipoles(freq_x, Zx_tot,freq_y, Zy_tot,part="imag", image_folder=image_folder, scale="linear")

# %%
image_folder = Path.cwd().parent / "Plots" 
# REAL
plot_longitudinal(freq_z, Zz_tot,part="real", image_folder=image_folder, scale="linear")

# IMAG
plot_longitudinal(freq_z, Zz_tot,part="imag", image_folder=image_folder, scale="linear")
